# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
#import random

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
combined_study_df = pd.merge(mouse_metadata,study_results,how='outer',on='Mouse ID')

# Display the data table for preview

combined_study_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4
#
# [1893 rows x 8 columns]

# %%
clean_study_df = combined_study_df.drop_duplicates(['Mouse ID','Timepoint'],keep=False)
total = len(clean_study_df['Mouse ID'].unique())
total
# Out:
# 249

# %%
clean_study_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4
#
# [1883 rows x 8 columns]

# %%
# Generate a summary statistics table consisting of the mean, median, variance, 
# standard deviation, and SEM of the tumor volume for each drug regimen.

summary_stat_table = clean_study_df.groupby(['Drug Regimen']).agg({'Tumor Volume (mm3)':
                                                                   ['mean','median','var','std','sem']})
summary_stat_table = summary_stat_table.reset_index(drop=False)
summary_stat_table
# Out:
#   Drug Regimen Tumor Volume (mm3)
#                              mean     median        var       std       sem
# 0    Capomulin          40.675741  41.557809  24.947764  4.994774  0.329346
# 1     Ceftamin          52.591172  51.776157  39.290177  6.268188  0.469821
# 2    Infubinol          52.884795  51.820584  43.128684  6.567243  0.492236
# 3     Ketapril          55.235638  53.698743  68.553577  8.279709  0.603860
# 4     Naftisol          54.331565  52.509285  66.173479  8.134708  0.596466
# 5      Placebo          54.033581  52.288934  61.168083  7.821003  0.581331
# 6     Propriva          52.458254  50.854632  44.053659  6.637293  0.540135
# 7     Ramicane          40.216745  40.673236  23.486704  4.846308  0.320955
# 8     Stelasyn          54.233149  52.431737  59.450562  7.710419  0.573111
# 9    Zoniferol          53.236507  51.818479  48.533355  6.966589  0.516398

# %%
# Generate a summary statistics table consisting of the mean, median, variance, 
# standard deviation, and SEM of the tumor volume for each drug regimen.

trial_drugs = []
tumor_average = []
tumor_median = []
tumor_var = []
tumor_std = []
tumor_sem = []

for drug in clean_study_df['Drug Regimen']:
    if drug in trial_drugs:
        continue
    else:
        # append drug name into list 
        trial_drugs.append(drug)
        
        # locate tumor volume for associated with each drug
        rex = clean_study_df.loc[clean_study_df['Drug Regimen']==drug,['Tumor Volume (mm3)']]
        
        # calculate summary statistics for each drug
        mean_d = rex.mean()
        med_d = rex.median()
        var_d = np.var(rex)
        std_d = np.std(rex)
        sem_d = st.sem(rex)
        
        # append summary statistics for each drug into list above
        tumor_average.append(mean_d[0])
        tumor_median.append(med_d[0])
        tumor_var.append(var_d[0])
        tumor_std.append(std_d[0])
        tumor_sem.append(sem_d[0])
        


# create new data fram to hold the summary statistics        
summary_table = pd.DataFrame({'Drug Regimen':trial_drugs,
                              'Tumor Mean':tumor_average,
                              'Tumor Median':tumor_median,
                              'Tumor Variance':tumor_var,
                              'Tumor STD':tumor_std,
                              'Tumor SEM':tumor_sem})
summary_table = summary_table.sort_values(['Drug Regimen'])
summary_table
# Out:
#   Drug Regimen  Tumor Mean  Tumor Median  Tumor Variance  Tumor STD  Tumor SEM
# 1    Capomulin   40.675741     41.557809       24.839296   4.983904   0.329346
# 4     Ceftamin   52.591172     51.776157       39.069446   6.250556   0.469821
# 2    Infubinol   52.884795     51.820584       42.886388   6.548770   0.492236
# 7     Ketapril   55.235638     53.698743       68.188930   8.257659   0.603860
# 9     Naftisol   54.331565     52.509285       65.817708   8.112811   0.596466
# 3      Placebo   54.033581     52.288934       60.830138   7.799368   0.581331
# 8     Propriva   52.458254     50.854632       43.761912   6.615279   0.540135
# 0     Ramicane   40.216745     40.673236       23.383692   4.835669   0.320955
# 5     Stelasyn   54.233149     52.431737       59.122106   7.689090   0.573111
# 6    Zoniferol   53.236507     51.818479       48.266689   6.947423   0.516398

# %%
#Generate a bar plot using both Pandas's `DataFrame.plot()` and Matplotlib's `pyplot` 
#that shows the total number of measurements taken for each treatment regimen throughout the course of the study.

group_study_df = clean_study_df.groupby(['Drug Regimen']).count()
group_study_df = group_study_df.reset_index(drop=False)


x_axis = np.arange(len(group_study_df))
y_axis = group_study_df['Tumor Volume (mm3)']
tick_location = [value for value in x_axis]

## Plot Bar Graph
plt.figure(figsize=(15,9))
plt.bar(x_axis,y_axis)
plt.xticks(tick_location,group_study_df['Drug Regimen'],rotation=45,fontsize=14)
plt.title('Total Measurements by Treatment Regimen',fontsize=20)
plt.xlabel('Treatment Regimen',fontsize=16)
plt.ylabel('Tumor Volume',fontsize=16)
plt.ylim(0,250)


plt.show()

# %%
## Graph pandas


plot_pandas = group_study_df['Tumor Volume (mm3)'].plot(kind='bar',xlabel='Treatment Regimen',ylabel='Tumor Volume',
                                                        title='Total Measurements by Treatment Regimen',legend=True,
                                                        figsize=(15,9),rot=45,ylim=(0,250))

#plt.xticks(tick_location,group_study_df['Drug Regimen'],rotation='45',fontsize=11)
#plt.xlabel('Treatment Regimen',fontsize=12)
#plt.ylabel('Tumor Volume',fontsize=12)
#plt.ylim(0,250)
#plt.show()

# %%
## Generate a pie plot using both Pandas's `DataFrame.plot()` and Matplotlib's `pyplot` 
## that shows the distribution of female or male mice in the study.

group_gender_df = clean_study_df.groupby('Sex').count()

# %%
pie_chart = group_gender_df['Tumor Volume (mm3)'].plot(kind='pie',autopct='%1.1f%%',fontsize=14)

# %%
new_df = group_gender_df.reset_index(drop=False)


labels = new_df['Sex']
size = new_df['Tumor Volume (mm3)']
plt.pie(size,labels=labels,autopct='%1.1f%%')


plt.show()

# %%
## Calculate the final tumor volume of each mouse across four of the most promising treatment regimens: 
## Capomulin, Ramicane, Infubinol, and Ceftamin. Calculate the quartiles and IQR and 
## quantitatively determine if there are any potential outliers across all four treatment regimens.

mouse_group_df = clean_study_df.groupby(['Mouse ID']).max()
mouse_group_df = mouse_group_df.reset_index(drop=False)
final_timepoints = mouse_group_df['Timepoint']

mouse_group_df
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0       a203    Infubinol  Female          20          23         45
# 1       a251    Infubinol  Female          21          25         45
# 2       a262      Placebo  Female          17          29         45
# 3       a275     Ceftamin  Female          20          28         45
# 4       a366     Stelasyn  Female          16          29         30
# ..       ...          ...     ...         ...         ...        ...
# 244     z435     Propriva  Female          12          26         10
# 245     z578     Ramicane    Male          11          16         45
# 246     z581    Infubinol  Female          24          25         45
# 247     z795     Naftisol  Female          13          29         45
# 248     z969     Naftisol    Male           9          30         45
#
#      Tumor Volume (mm3)  Metastatic Sites
# 0             67.973419                 2
# 1             65.525743                 1
# 2             70.717621                 4
# 3             62.999356                 3
# 4             63.440686                 1
# ..                  ...               ...
# 244           48.710661                 0
# 245           45.000000                 0
# 246           62.754451                 3
# 247           65.741070                 3
# 248           73.867845                 4
#
# [249 rows x 8 columns]

# %%
combined_study_df.loc[combined_study_df['Mouse ID']=='y793']
# Out:
#     Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 115     y793    Capomulin  Male          17          17          0
# 116     y793    Capomulin  Male          17          17          5
# 117     y793    Capomulin  Male          17          17         10
# 118     y793    Capomulin  Male          17          17         15
# 119     y793    Capomulin  Male          17          17         20
# 120     y793    Capomulin  Male          17          17         25
# 121     y793    Capomulin  Male          17          17         30
# 122     y793    Capomulin  Male          17          17         35
# 123     y793    Capomulin  Male          17          17         40
# 124     y793    Capomulin  Male          17          17         45
#
#      Tumor Volume (mm3)  Metastatic Sites
# 115           45.000000                 0
# 116           41.019913                 0
# 117           41.630010                 1
# 118           42.283665                 1
# 119           40.716428                 2
# 120           38.992734                 2
# 121           35.726023                 2
# 122           36.327870                 2
# 123           31.475411                 2
# 124           31.896238                 2

# %%
Capomulin = combined_study_df.loc[combined_study_df['Drug Regimen']=='Capomulin']
Ramicane = combined_study_df.loc[combined_study_df['Drug Regimen']=='Ramicane']
Infubinol = combined_study_df.loc[combined_study_df['Drug Regimen']=='Infubinol']
Ceftamin = combined_study_df.loc[combined_study_df['Drug Regimen']=='Ceftamin']

success_study_df = pd.concat([Capomulin,Ramicane,Infubinol,Ceftamin])

success_study_df = success_study_df.sort_values(['Mouse ID'],ascending=True)
lend = len(success_study_df['Mouse ID'].unique())

# %%
success_group_df = success_study_df.groupby(['Mouse ID']).max()
final_timepoints = success_group_df['Timepoint']

# %%
new_group_df = pd.merge(success_study_df,success_group_df,how='inner',on='Mouse ID')
new_group_df = new_group_df.drop(columns=['Drug Regimen_y','Sex_y','Age_months_y','Weight (g)_y','Metastatic Sites_y',
                                          'Tumor Volume (mm3)_y'])
new_group_df = new_group_df.rename(columns={'Drug Regimen_x':'Drug Regimen','Sex_x':'Sex','Age_months_x':'Age_months',
                                           'Weight (g)_x':'Weight (g)','Timepoint_x':'Timepoint',
                                            'Tumor Volume (mm3)_x':'Tumor Volume (mm3)',
                                           'Metastatic Sites_x':'Metastatic Sites','Timepoint_y':'Final Timepoint'})
new_group_df = new_group_df.sort_values(['Mouse ID','Timepoint'],ascending=[True,True])
new_group_df = new_group_df.reset_index(drop=True)
new_group_df
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0       a203    Infubinol  Female          20          23          0
# 1       a203    Infubinol  Female          20          23          5
# 2       a203    Infubinol  Female          20          23         10
# 3       a203    Infubinol  Female          20          23         15
# 4       a203    Infubinol  Female          20          23         20
# ..       ...          ...     ...         ...         ...        ...
# 809     z581    Infubinol  Female          24          25         25
# 810     z581    Infubinol  Female          24          25         30
# 811     z581    Infubinol  Female          24          25         35
# 812     z581    Infubinol  Female          24          25         40
# 813     z581    Infubinol  Female          24          25         45
#
#      Tumor Volume (mm3)  Metastatic Sites  Final Timepoint
# 0             45.000000                 0               45
# 1             48.508468                 0               45
# 2             51.852437                 1               45
# 3             52.777870                 1               45
# 4             55.173336                 1               45
# ..                  ...               ...              ...
# 809           54.316407                 2               45
# 810           56.286750                 2               45
# 811           58.628399                 3               45
# 812           60.053740                 3               45
# 813           62.754451                 3               45
#
# [814 rows x 9 columns]

# %%
some_new_df = new_group_df.loc[new_group_df['Timepoint']==new_group_df['Final Timepoint']]
some_new_df
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 9       a203    Infubinol  Female          20          23         45
# 19      a251    Infubinol  Female          21          25         45
# 29      a275     Ceftamin  Female          20          28         45
# 39      a411     Ramicane    Male           3          22         45
# 49      a444     Ramicane  Female          10          25         45
# ..       ...          ...     ...         ...         ...        ...
# 773     y769     Ceftamin  Female           6          27         45
# 783     y793    Capomulin    Male          17          17         45
# 793     y865     Ceftamin    Male          23          26         45
# 803     z578     Ramicane    Male          11          16         45
# 813     z581    Infubinol  Female          24          25         45
#
#      Tumor Volume (mm3)  Metastatic Sites  Final Timepoint
# 9             67.973419                 2               45
# 19            65.525743                 1               45
# 29            62.999356                 3               45
# 39            38.407618                 1               45
# 49            43.047543                 0               45
# ..                  ...               ...              ...
# 773           68.594745                 4               45
# 783           31.896238                 2               45
# 793           64.729837                 3               45
# 803           30.638696                 0               45
# 813           62.754451                 3               45
#
# [100 rows x 9 columns]

# %%
promising_drugs = []
for drug in new_group_df['Drug Regimen']:
    if drug in promising_drugs:
        continue
    else:
        promising_drugs.append(drug)
promising_drugs
# Out:
# ['Infubinol', 'Ceftamin', 'Ramicane', 'Capomulin']

# %%
## Calculate the IQR, Quartiles and outliers
quartiles = some_new_df['Tumor Volume (mm3)'].quantile([.25,.5,.75])
lowerq = quartiles[.25]
upperq = quartiles[.75]
iqr = upperq-lowerq
lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr) 

print(upper_bound)
print(upperq)
print(iqr)
print(lowerq)
print(lower_bound)

#outliers_df = some_new_df.loc[(some_new_df['Tumor Volume (mm3)']>=upper_bound) 
#                               | (some_new_df['Tumor Volume (mm3)']<=lower_bound)]
# Out:
# 94.04403868375002
# 59.930261755000004
# 22.74251795250001
# 37.187743802499995
# 3.0739668737499812

# %%
infubinol_plot = some_new_df.loc[some_new_df['Drug Regimen']=='Infubinol',['Tumor Volume (mm3)']]
ceftamin_plot = some_new_df.loc[some_new_df['Drug Regimen']=='Ceftamin',['Tumor Volume (mm3)']]
ramicane_plot = some_new_df.loc[some_new_df['Drug Regimen']=='Ramicane',['Tumor Volume (mm3)']]
capomulin_plot = some_new_df.loc[some_new_df['Drug Regimen']=='Capomulin',['Tumor Volume (mm3)']]

# %%
fig2, axs = plt.subplots(2,2,figsize=(20,10))

axs[0,0].boxplot(infubinol_plot)
axs[0,0].set_title('Infubinol')
#axs[0,0].set_ylim(lower_bound + 1,upper_bound + 1)


axs[0,1].boxplot(ceftamin_plot)
axs[0,1].set_title('Ceftamin')
#axs[0,1].set_ylim(lower_bound + 1,upper_bound + 1)

axs[1,0].boxplot(ramicane_plot)
axs[1,0].set_title('Ramicane')
#axs[1,0].set_ylim(lower_bound + 1,upper_bound + 1)

axs[1,1].boxplot(capomulin_plot)
axs[1,1].set_title('Capomulin')
#axs[1,1].set_ylim(lower_bound + 1,upper_bound + 1)

plt.show()

# %%
capomulin_df = some_new_df.loc[some_new_df['Drug Regimen']=='Capomulin']
capomulin_df = capomulin_df.reset_index(drop=True)
capomulin_df
# Out:
#    Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0      b128    Capomulin  Female           9          22         45
# 1      b742    Capomulin    Male           7          21         45
# 2      f966    Capomulin    Male          16          17         20
# 3      g288    Capomulin    Male           3          19         45
# 4      g316    Capomulin  Female          22          22         45
# 5      i557    Capomulin  Female           1          24         45
# 6      i738    Capomulin  Female          23          20         45
# 7      j119    Capomulin  Female           7          23         45
# 8      j246    Capomulin  Female          21          21         35
# 9      l509    Capomulin    Male          17          21         45
# 10     l897    Capomulin    Male          17          19         45
# 11     m601    Capomulin    Male          22          17         45
# 12     m957    Capomulin  Female           3          19         45
# 13     r157    Capomulin    Male          22          25         15
# 14     r554    Capomulin  Female           8          17         45
# 15     r944    Capomulin    Male          12          25         45
# 16     s185    Capomulin  Female           3          17         45
# 17     s710    Capomulin  Female           1          23         45
# 18     t565    Capomulin  Female          20          17         45
# 19     u364    Capomulin    Male          18          17         45
# 20     v923    Capomulin  Female          19          21         45
# 21     w150    Capomulin    Male          23          23         10
# 22     w914    Capomulin    Male          24          21         45
# 23     x401    Capomulin  Female          16          15         45
# 24     y793    Capomulin    Male          17          17         45
#
#     Tumor Volume (mm3)  Metastatic Sites  Final Timepoint
# 0            38.982878                 2               45
# 1            38.939633                 0               45
# 2            30.485985                 0               20
# 3            37.074024                 1               45
# 4            40.159220                 2               45
# 5            47.685963                 1               45
# 6            37.311846                 2               45
# 7            38.125164                 1               45
# 8            38.753265                 1               35
# 9            41.483008                 3               45
# 10           38.846876                 1               45
# 11           28.430964                 1               45
# 12           33.329098                 1               45
# 13           46.539206                 0               15
# 14           32.377357                 3               45
# 15           41.581521                 2               45
# 16           23.343598                 1               45
# 17           40.728578                 1               45
# 18           34.455298                 0               45
# 19           31.023923                 3               45
# 20           40.658124                 2               45
# 21           39.952347                 0               10
# 22           36.041047                 2               45
# 23           28.484033                 0               45
# 24           31.896238                 2               45

# %%
test = np.random.seed(0)
rand_mouse = some_new_df.sample(test)
mouse = rand_mouse.iloc[0,0]

mouse_df = clean_study_df.loc[clean_study_df['Mouse ID']==mouse]
mouse_df
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 351     g316    Capomulin  Female          22          22          0
# 352     g316    Capomulin  Female          22          22          5
# 353     g316    Capomulin  Female          22          22         10
# 354     g316    Capomulin  Female          22          22         15
# 355     g316    Capomulin  Female          22          22         20
# 356     g316    Capomulin  Female          22          22         25
# 357     g316    Capomulin  Female          22          22         30
# 358     g316    Capomulin  Female          22          22         35
# 359     g316    Capomulin  Female          22          22         40
# 360     g316    Capomulin  Female          22          22         45
#
#      Tumor Volume (mm3)  Metastatic Sites
# 351           45.000000                 0
# 352           44.022752                 0
# 353           44.502042                 0
# 354           45.216743                 0
# 355           45.933322                 1
# 356           46.809225                 1
# 357           44.221480                 2
# 358           44.702833                 2
# 359           45.565821                 2
# 360           40.159220                 2

# %%
xax = mouse_df['Timepoint']
yax = mouse_df['Tumor Volume (mm3)']
plt.plot(xax,yax,marker='^')

# %%
### Average Tumor Volume

ave_group_df = some_new_df.groupby(['Mouse ID','Drug Regimen']).mean()
ave_group_df = ave_group_df.reset_index(drop=False)
cap_ave_group_df = ave_group_df.loc[ave_group_df['Drug Regimen']=='Capomulin']
cap_ave_group_df
# Out:
#    Mouse ID Drug Regimen  Age_months  Weight (g)  Timepoint  \
# 9      b128    Capomulin           9          22         45
# 12     b742    Capomulin           7          21         45
# 24     f966    Capomulin          16          17         20
# 25     g288    Capomulin           3          19         45
# 26     g316    Capomulin          22          22         45
# 32     i557    Capomulin           1          24         45
# 33     i738    Capomulin          23          20         45
# 34     j119    Capomulin           7          23         45
# 35     j246    Capomulin          21          21         35
# 45     l509    Capomulin          17          21         45
# 49     l897    Capomulin          17          19         45
# 51     m601    Capomulin          22          17         45
# 53     m957    Capomulin           3          19         45
# 64     r157    Capomulin          22          25         15
# 65     r554    Capomulin           8          17         45
# 68     r944    Capomulin          12          25         45
# 70     s185    Capomulin           3          17         45
# 72     s710    Capomulin           1          23         45
# 73     t565    Capomulin          20          17         45
# 78     u364    Capomulin          18          17         45
# 82     v923    Capomulin          19          21         45
# 83     w150    Capomulin          23          23         10
# 88     w914    Capomulin          24          21         45
# 90     x401    Capomulin          16          15         45
# 96     y793    Capomulin          17          17         45
#
#     Tumor Volume (mm3)  Metastatic Sites  Final Timepoint
# 9            38.982878                 2               45
# 12           38.939633                 0               45
# 24           30.485985                 0               20
# 25           37.074024                 1               45
# 26           40.159220                 2               45
# 32           47.685963                 1               45
# 33           37.311846                 2               45
# 34           38.125164                 1               45
# 35           38.753265                 1               35
# 45           41.483008                 3               45
# 49           38.846876                 1               45
# 51           28.430964                 1               45
# 53           33.329098                 1               45
# 64           46.539206                 0               15
# 65           32.377357                 3               45
# 68           41.581521                 2               45
# 70           23.343598                 1               45
# 72           40.728578                 1               45
# 73           34.455298                 0               45
# 78           31.023923                 3               45
# 82           40.658124                 2               45
# 83           39.952347                 0               10
# 88           36.041047                 2               45
# 90           28.484033                 0               45
# 96           31.896238                 2               45

# %%
## scatter

weight = capomulin_df['Weight (g)']
ave_tumor_vol = cap_ave_group_df['Tumor Volume (mm3)']
nax = capomulin_df['Mouse ID']

plt.scatter(weight,ave_tumor_vol)
plt.show()

# %%
## Correlation

correlation = st.pearsonr(weight,ave_tumor_vol)
correlation
# Out:
# (0.8767060403658113, 9.08442908867363e-09)

# %%
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(weight,ave_tumor_vol)
(slope, intercept, rvalue, pvalue, stderr)
line_eq = slope*weight + intercept
plt.scatter(weight,ave_tumor_vol)
plt.plot(weight,line_eq,color='r')
plt.show()
